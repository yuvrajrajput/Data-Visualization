# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/content/bbkivines.csv')
data
# Out:
#      Unnamed: 0                                              Title  \
# 0             0  BB Ki Vines Productions | Haseen Raat | Taaza ...
# 1             1               BB Ki Vines | Angry Masterji Part 16
# 2             2  BB Ki Vines Productions- Taaza Khabar | Hotsta...
# 3             3             BB Ki Vines (Vlog #8)- | BB in Dubai |
# 4             4  BB Ki Vines Productions - Taaza Khabar | Now F...
# ..          ...                                                ...
# 180         180  Raaste Mei Hu! | Jhoota Dost Late Lateef | BB ...
# 181         181       BB Ki Vines- | Abusing in front of parents |
# 182         182  Kutiya Khafa Saand Bewafa | Gaur Se Dekhiye | ...
# 183         183  Bittu Ki Lottery Lagi Hai | Chori Mein Twist |...
# 184         184            BB Ki Vines- | Bhai-Zoned..Attyachaar |
#
#                  Publish_date       views comments likes Duration  \
# 0                 21 Jan 2023  10,866,369   17,628  500K     3:19
# ...

# %%
df = data.copy()

# %%
df
# Out:
#      Unnamed: 0                                              Title  \
# 0             0  BB Ki Vines Productions | Haseen Raat | Taaza ...
# 1             1               BB Ki Vines | Angry Masterji Part 16
# 2             2  BB Ki Vines Productions- Taaza Khabar | Hotsta...
# 3             3             BB Ki Vines (Vlog #8)- | BB in Dubai |
# 4             4  BB Ki Vines Productions - Taaza Khabar | Now F...
# ..          ...                                                ...
# 180         180  Raaste Mei Hu! | Jhoota Dost Late Lateef | BB ...
# 181         181       BB Ki Vines- | Abusing in front of parents |
# 182         182  Kutiya Khafa Saand Bewafa | Gaur Se Dekhiye | ...
# 183         183  Bittu Ki Lottery Lagi Hai | Chori Mein Twist |...
# 184         184            BB Ki Vines- | Bhai-Zoned..Attyachaar |
#
#                  Publish_date       views comments likes Duration  \
# 0                 21 Jan 2023  10,866,369   17,628  500K     3:19
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    185 non-null    int64
#  1   Title         185 non-null    object
#  2   Publish_date  185 non-null    object
#  3   views         185 non-null    object
#  4   comments      185 non-null    object
#  5   likes         185 non-null    object
#  6   Duration      185 non-null    object
#  7   video_link    185 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 11.7+ KB

# %%
df = df.drop(['Unnamed: 0'], axis = 1)
df
# Out:
#                                                  Title  \
# 0    BB Ki Vines Productions | Haseen Raat | Taaza ...
# 1                 BB Ki Vines | Angry Masterji Part 16
# 2    BB Ki Vines Productions- Taaza Khabar | Hotsta...
# 3               BB Ki Vines (Vlog #8)- | BB in Dubai |
# 4    BB Ki Vines Productions - Taaza Khabar | Now F...
# ..                                                 ...
# 180  Raaste Mei Hu! | Jhoota Dost Late Lateef | BB ...
# 181       BB Ki Vines- | Abusing in front of parents |
# 182  Kutiya Khafa Saand Bewafa | Gaur Se Dekhiye | ...
# 183  Bittu Ki Lottery Lagi Hai | Chori Mein Twist |...
# 184            BB Ki Vines- | Bhai-Zoned..Attyachaar |
#
#                  Publish_date       views comments likes Duration  \
# 0                 21 Jan 2023  10,866,369   17,628  500K     3:19
# 1     Premiered on 3 Jan 2023  16,671,177   62,736  1.9M    10:41
# 2    Premiered on 13 Dec 2022  19,973,395   31,389  639K     1:50
# ...

# %% [markdown]
# 1.   Most like video
# 2.   Most comment video
# 3.   Most views video
# 4.   Top 10 longest videos

# %%
import plotly.express as px

# %% [markdown]
# **Most like on video**

# %%
fig = px.bar(df, y="Title", x="likes", orientation='h')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Most comments on video**

# %%
fig = px.bar(df, y="Title", x="comments", orientation='h')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Most views on video**

# %%
fig = px.bar(df, y="Title", x="views", orientation='h')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ****Most Duration of video****

# %%
fig = px.bar(df, y="Title", x="Duration", orientation='h')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
